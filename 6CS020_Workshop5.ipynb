# %% [markdown]
# <a href="https://colab.research.google.com/github/prinsha13/6CS020_BigData/blob/main/6CS020_Workshop5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Weather Dataset

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\admin\onedrive\desktop\prinsha2\semester-6\big data\bigdata_env\lib\site-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\admin\onedrive\desktop\prinsha2\semester-6\big data\bigdata_env\lib\site-packages (from pymongo) (2.7.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Necessary imports
import pymongo
from pprint import pprint
from bson.objectid import ObjectId
import string
import operator
import re

#Print out the version pf pymongo
print(pymongo.version)
# Out:
# 4.11.3

# %% [markdown]
# 2. Connecting to MongoDB

# %%
yourUniId = "2331421"
url = "mongodb://localhost:27017/"
myDatabase = "db_" + yourUniId
myclient = pymongo.MongoClient(url)
print(myclient)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %% [markdown]
# 3. Connecting to your Database

# %%
mydb = myclient[myDatabase] #Connect to database
print(mydb)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'db_2331421')

# %%
#Ping the server to check if the connection is active and working
myclient.admin.command('ping')
# Out:
# {'ok': 1.0}

# %% [markdown]
# 4. Using MongoDB from Python

# %%
#Find the collections in the database
mydb.list_collection_names()
# Out:
# ['newWeather', 'weather', 'projWeather']

# %%
# Set a variable called 'wcol' to the weather collection
wcol = mydb['weather']

# %% [markdown]
# 5. Workbook Examples
# The following shows examples from the MongoDB workbook. The Mongo Client command is shown as a comment.
# The comments will also mention any variations in syntax.

# %%
# db.weather.count()
# Syntax difference: count() is depreciated so have to use a Collection's␣
       #↪count_document function instead:

print(wcol.count_documents({}))
# Out:
# 250

# %%
#db.weather.finOne()
#findOne() is called find_one() in python
wtweets = wcol.find_one()
print(wtweets)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3a'), 'contributors': None, 'truncated': True, 'text': '@Lillybetmax @VisitCairngrms @VisitScotland @ScotsMagazine @BBCSpringwatch @uknationalparks @bbcweather @metoffice… https://t.co/NcYieNDbRs', 'is_quote_status': False, 'in_reply_to_status_id': 1224417619173834752, 'id': 1224423049782603783, 'favorite_count': 0, 'entities': {'symbols': [], 'user_mentions': [{'id': 1139793943032414208, 'indices': [0, 12], 'id_str': '1139793943032414208', 'screen_name': 'Lillybetmax', 'name': 'Elizabeth B'}, {'id': 20714374, 'indices': [13, 28], 'id_str': '20714374', 'screen_name': 'VisitCairngrms', 'name': 'VisitCairngorms.com'}, {'id': 16557472, 'indices': [29, 43], 'id_str': '16557472', 'screen_name': 'VisitScotland', 'name': 'VisitScotland'}, {'id': 132563048, 'indices': [44, 58], 'id_str': '132563048', 'screen_name': 'ScotsMagazine', 'name': 'The Scots Magazine'}, {'id': 71229689, 'indices': [59, 74], 'id_str': '71229689', 'screen_name': 'BBCSpringwatch', 'name': 'BBC Springwatch'}, {'id': 23068217, 'indices': [75, 91], 'id_str': '23068217', 'screen_name': 'uknationalparks', 'name': 'National Parks UK'}, {'id': 142614009, 'indices': [92, 103], 'id_str': '142614009', 'screen_name': 'bbcweather', 'name': 'BBC Weather'}, {'id': 19282280, 'indices': [104, 114], 'id_str': '19282280', 'screen_name': 'metoffice', 'name': 'Met Office'}], 'hashtags': [], 'urls': [{'url': 'https://t.co/NcYieNDbRs', 'indices': [116, 139], 'expanded_url': 'https://twitter.com/i/web/status/1224423049782603783', 'display_url': 'twitter.com/i/web/status/1…'}]}, 'retweeted': False, 'coordinates': None, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'in_reply_to_screen_name': 'Lillybetmax', 'in_reply_to_user_id': 1139793943032414208, 'retweet_count': 0, 'id_str': '1224423049782603783', 'favorited': False, 'user': {'follow_request_sent': False, 'has_extended_profile': False, 'profile_use_background_image': True, 'default_profile_image': False, 'id': 789877778, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'verified': False, 'translator_type': 'none', 'profile_text_color': '333333', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071841068604362752/1zZXf46n_normal.jpg', 'profile_sidebar_fill_color': 'DDEEF6', 'entities': {'url': {'urls': [{'url': 'https://t.co/U3ebR2ttGQ', 'indices': [0, 23], 'expanded_url': 'http://www.andyhoward.co.uk', 'display_url': 'andyhoward.co.uk'}]}, 'description': {'urls': []}}, 'followers_count': 6974, 'profile_sidebar_border_color': 'C0DEED', 'id_str': '789877778', 'profile_background_color': 'C0DEED', 'listed_count': 135, 'is_translation_enabled': False, 'utc_offset': None, 'statuses_count': 22838, 'description': 'Pro. wildlife photographer/guide & author. Workshops & tours in Scotland. Keela clothing partner. Leica ambassador. Occasional TV appearances.', 'friends_count': 405, 'location': 'Highlands of Scotland', 'profile_link_color': '1DA1F2', 'profile_image_url': 'http://pbs.twimg.com/profile_images/1071841068604362752/1zZXf46n_normal.jpg', 'following': False, 'geo_enabled': True, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/789877778/1573828811', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'screen_name': 'highland_andy', 'lang': None, 'profile_background_tile': False, 'favourites_count': 41272, 'name': 'Andy Howard', 'notifications': False, 'url': 'https://t.co/U3ebR2ttGQ', 'created_at': 'Wed Aug 29 18:18:11 +0000 2012', 'contributors_enabled': False, 'time_zone': None, 'protected': False, 'default_profile': True, 'is_translator': False}, 'geo': None, 'in_reply_to_user_id_str': '1139793943032414208', 'lang': 'en', 'created_at': 'Mon Feb 03 20:02:58 +0000 2020', 'in_reply_to_status_id_str': '1224417619173834752', 'place': None, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}}

# %%
#pretty() is not a function in Python
#Use pprint instead
pprint(wtweets)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3a'),
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Feb 03 20:02:58 +0000 2020',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1224423049782603783',
#                         'indices': [116, 139],
#                         'url': 'https://t.co/NcYieNDbRs'}],
#               'user_mentions': [{'id': 1139793943032414208,
#                                  'id_str': '1139793943032414208',
#                                  'indices': [0, 12],
#                                  'name': 'Elizabeth B',
#                                  'screen_name': 'Lillybetmax'},
#                                 {'id': 20714374,
#                                  'id_str': '20714374',
#                                  'indices': [13, 28],
#                                  'name': 'VisitCairngorms.com',
#                                  'screen_name': 'VisitCairngrms'},
#                                 {'id': 16557472,
#                                  'id_str': '16557472',
#                                  'indices': [29, 43],
#                                  'name': 'VisitScotland',
#                                  'screen_name': 'VisitScotland'},
#                                 {'id': 132563048,
#                                  'id_str': '132563048',
#                                  'indices': [44, 58],
#                                  'name': 'The Scots Magazine',
#                                  'screen_name': 'ScotsMagazine'},
#                                 {'id': 71229689,
#                                  'id_str': '71229689',
#                                  'indices': [59, 74],
#                                  'name': 'BBC Springwatch',
#                                  'screen_name': 'BBCSpringwatch'},
#                                 {'id': 23068217,
#                                  'id_str': '23068217',
#                                  'indices': [75, 91],
#                                  'name': 'National Parks UK',
#                                  'screen_name': 'uknationalparks'},
#                                 {'id': 142614009,
#                                  'id_str': '142614009',
#                                  'indices': [92, 103],
#                                  'name': 'BBC Weather',
#                                  'screen_name': 'bbcweather'},
#                                 {'id': 19282280,
#                                  'id_str': '19282280',
#                                  'indices': [104, 114],
#                                  'name': 'Met Office',
#                                  'screen_name': 'metoffice'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1224423049782603783,
#  'id_str': '1224423049782603783',
#  'in_reply_to_screen_name': 'Lillybetmax',
#  'in_reply_to_status_id': 1224417619173834752,
#  'in_reply_to_status_id_str': '1224417619173834752',
#  'in_reply_to_user_id': 1139793943032414208,
#  'in_reply_to_user_id_str': '1139793943032414208',
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/#!/download/ipad" '
#            'rel="nofollow">Twitter for iPad</a>',
#  'text': '@Lillybetmax @VisitCairngrms @VisitScotland @ScotsMagazine '
#          '@BBCSpringwatch @uknationalparks @bbcweather @metoffice… '
#          'https://t.co/NcYieNDbRs',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed Aug 29 18:18:11 +0000 2012',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'Pro. wildlife photographer/guide & author. Workshops '
#                          '& tours in Scotland. Keela clothing partner. Leica '
#                          'ambassador. Occasional TV appearances.',
#           'entities': {'description': {'urls': []},
#                        'url': {'urls': [{'display_url': 'andyhoward.co.uk',
#                                          'expanded_url': 'http://www.andyhoward.co.uk',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/U3ebR2ttGQ'}]}},
#           'favourites_count': 41272,
#           'follow_request_sent': False,
#           'followers_count': 6974,
#           'following': False,
#           'friends_count': 405,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 789877778,
#           'id_str': '789877778',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 135,
#           'location': 'Highlands of Scotland',
#           'name': 'Andy Howard',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/789877778/1573828811',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1071841068604362752/1zZXf46n_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1071841068604362752/1zZXf46n_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'highland_andy',
#           'statuses_count': 22838,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'https://t.co/U3ebR2ttGQ',
#           'utc_offset': None,
#           'verified': False}}

# %%
#Show distinct languages
#db.weather.distinct("lang")
wcol.distinct("lang")
# Out:
# ['English', 'en', 'es', 'unknown']

# %%
#Show distinct texts
#db.weather.distinct("text")
wcol.distinct("text")
# Out:
# ['#sunset over #m6n #rushhour @bbcmtd @bbcweather Birmingham https://t.co/xfmiSqR0u3',
#  '.@bbcweather *Again* 1430  GMT @bbcworld news weather summary: presenter standing in front of satellite video for P… https://t.co/oXmRIxigH2',
#  '@1PaulMichael @VisitScotland @bbcweather @BBCScotland I must say it took me over a minute to register that it’s Ben… https://t.co/Z18sbi9nLZ',
#  '@1PaulMichael @VisitScotland @bbcweather @BBCScotland Indeed my friend , was by chance driving by and couldn’t resist',
#  '@AbhaPaulina @VisitScotland @bbcweather @BBCScotland At this time of year the Ben would often be capped in snow. Beautiful sight.',
#  '@AbhaPaulina @VisitScotland @bbcweather @BBCScotland Gorgeous scenes on Saturday 😍',
#  "@Alex_Mulcrow93 @bbcweather Our flowers and trees have started too. Blossom already. It's not normal",
#  '@AndiOram4 @MickeyJPrior @bbcweather Two decent articles on the MetO site...\n\nhttps://t.co/UX1nYOzn3p\n\n^ explains t… https://t.co/0zj1110yJo',
#  '@AnjanaGadgil @Kate_Kinsella @BrownieLB_1 @SallyTaylor_tv @BBCWeather @BBCSWWeather @karenjane16ka @KeeleyDonovan… https://t.co/AD6We1sEct',
#  '@BBCBreakfast @bbcweather ‘in the north of the country’ - repeat after me UK / Britain is not a country - UK / Brit… https://t.co/51KeFQLgkm',
#  '@BBCWthrWatchers @bbcweather @carolkirkwood @Hudsonweather @Abbiedew @KeeleyDonovan @katerinaweather @lottyleeming… https://t.co/I5bZjX7Dh8',
#  "@Dave91632231 @bbcweather It's winter. It's supposed to be cold. There are meant to be frosts. The absence of them… https://t.co/G1Jlpf5kr1",
#  '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Maybe get a chance to put the winter tyres to test....at last ☃️🤔😂',
#  '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Oh dear! No sign of a cold snap then ? ❄️☃️',
#  '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Ooohhj ! Severe wind 😮',
#  '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Those iso bars are quite close 😱',
#  '@GeordieCanary @StormHour @ChrisPage90 @WeatherAisling @BBCWthrWatchers @bbcweather @LensAreLive Oh yes 😎 https://t.co/QA6TsrZKzQ',
#  '@JeanneHoffa @theroyalparks @WildLondon @WWTLondon @StormHour @photohour @bbcweather @SimonOKing @SallyWeather @itvweather Thank you Jeanne',
#  "@JudePri14876016 @bbcweather You'll either drown or starve to death if we get to that point.",
#  '@Lillybetmax @VisitCairngrms @VisitScotland @ScotsMagazine @BBCSpringwatch @uknationalparks @bbcweather @metoffice… https://t.co/NcYieNDbRs',
#  "@Menkvi @bbcweather This isn't climate change just a plume of hot air which has been drawing hot air up for about a… https://t.co/lpwHdFe6Tw",
#  '@MickeyJPrior @bbcweather Air frost occurs when the air temp at 2 metres reaches -0°C. A ground frost can occur wit… https://t.co/JvVoEUQla3',
#  '@MickeyJPrior @bbcweather Well the ground temperature is recorded just above the ground I believe just above the su… https://t.co/n1M2ase24m',
#  '@Official_WXUK @MickeyJPrior @bbcweather Is there anything good I can read up about frosts and forecasting them.',
#  '@Official_WXUK @bbcweather The air temperature at ground level must be 0° to cause the ice crystals on the surface to form?',
#  '@Omi_233 @bbcweather What BBC propaganda?',
#  '@SGIRE82 @VisitCairngrms @VisitScotland @ScotsMagazine @BBCSpringwatch @uknationalparks @bbcweather @metoffice @BBCEarth @BBCOutofDoors 🙏😊👍',
#  '@Silligilli @porridgebrain @cairnstoon @bbcweather',
#  '@StevePayne2018 @bbcweather Ah! Global warming? Not ideal, but the line of business I’m in I don’t like the cold wi… https://t.co/loXcBsUdEM',
#  '@StevePayne2018 @bbcweather Why? I thought it would be good? Thanks in advance for an explanation! 👍🏼',
#  '@TravelwithPOwer @ThePhotoHour @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour Thank you',
#  '@WAWilliams15 @DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales ISO bars? Are they protein bars, they sound nice 😋 😉',
#  '@YorkshireBird_ @porridgebrain @LevParikian @bbcweather',
#  '@alannah213 @barrabest @WeatherCee @BBCNewsNI @BBCTravelShow @DiscoverNI @bbcweather Great sky ...',
#  '@bbcpointswest @bbcweather Portishead Marina https://t.co/5VDnw5Jf8x',
#  '@bbcweather 27 degrees across Northwest Italy too.',
#  '@bbcweather @BBCScotWeather We have some fairly brisk air in Kirkwall today anyway - not much chance of frost I suspect 🤣',
#  '@bbcweather @BBCWthrWatchers @BBCLookEast',
#  '@bbcweather Beautiful day to be had by everyone there then!',
#  '@bbcweather Blimey!!!! 🥶🥶🥶 https://t.co/zG2gaYZeO2',
#  '@bbcweather Camborne in Cornwall as well I believe 👍',
#  '@bbcweather Crazy. Please tell me that we will get some colder weather in kent? Every day is in double figures and… https://t.co/TkmYJ9joV9',
#  "@bbcweather Good let's make 25c the average",
#  '@bbcweather Hope not, we need to fight back against this.',
#  '@bbcweather Hope the trend stays for the weekend..',
#  '@bbcweather Incredible',
#  '@bbcweather Nothing new here, more climate propaganda and hysteria from the BBC. The license fee really must go and… https://t.co/gdIroLIRwx',
#  '@bbcweather Perhaps dry hot summers could become the norm in Scotland',
#  '@bbcweather Southerly wind ya NERDS, its NOT climate change ffs',
#  '@bbcweather The ocean always helps lol.',
#  "@bbcweather This isn't good news 🙁",
#  "@bbcweather We're more likely to see wetter summers in Scotland due to the jet stream not moving as far north as it… https://t.co/jQZP5ghcl3",
#  "@bbcweather What's the difference between air and ground frost?",
#  "@bbcweather Where are the 'I saw snow in winter so climate change isn't real' people",
#  '@bbcweather Yeah right...I call bullshit!!',
#  '@bbcweather Yep, with #WeatherModification....',
#  '@bbcweather has done me dirty today, light showers? What a load of crap',
#  '@bbcweather https://t.co/7fIC2ysZCD',
#  '@bbcweather https://t.co/QGpJ97PHQQ',
#  '@bbcweather 😱',
#  '@every_station @ScotRail @AlexHynes @bbcweather Great photo.',
#  '@every_station @ScotRail @AlexHynes @bbcweather I saw that train at Carsile about 30 minutes ago, I’m on an avanti… https://t.co/IJsjzTb25C',
#  '@every_station @ScotRail @AlexHynes @bbcweather I was there the other day 😊',
#  '@festinagirl yep https://t.co/4s3yS1iPiS and as models predicted as we warm up we get more extremes, all the warmes… https://t.co/eXVbfB3Nlr',
#  '@frasergj @StirUni @BBCScotWeather @BBCAimsir @bbcweather @metoffice @BBCWthrWatchers @BBCCountryfile @BBCEarth… https://t.co/G10xHKL07y',
#  '@goldfinches12 @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour Thank you Mart… https://t.co/fDMppTyn9L',
#  '@highland_andy @VisitCairngrms @VisitScotland @ScotsMagazine @BBCSpringwatch @uknationalparks @bbcweather… https://t.co/OAc67eH24Q',
#  '@highland_andy @VisitCairngrms @VisitScotland @ScotsMagazine @BBCSpringwatch @uknationalparks @bbcweather… https://t.co/rblo0HfOC5',
#  '@hugysmum @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour It’s a bird! Thank… https://t.co/FTkAGboel2',
#  '@hugysmum @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour 🦅',
#  '@lana_preston @StirUni @BBCScotWeather @BBCAimsir @bbcweather @metoffice @BBCWthrWatchers @BBCCountryfile @BBCEarth… https://t.co/48dWvHyDcT',
#  '@owz09 @DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales 😁',
#  '@ruths_gallery @ThePhotoHour @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour Cool! 👍',
#  '@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour Is it a bird..… https://t.co/vUJmMWVVYn',
#  "@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour That's an amaz… https://t.co/4CfjDIwF44",
#  '@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather @SimonOKing @StormHour @ThePhotoHour 😱😱😱😱',
#  '@ruths_gallery @theroyalparks @WildLondon @WWTLondon @StormHour @photohour @bbcweather @SimonOKing @SallyWeather @itvweather Lovely. 😊',
#  '@simon_weather @StormchaserUKEU @carlharlott @DanHolley @stormbell @Lowweather @TheSnowDreamer @iainG81 @MetRyan96… https://t.co/4q2oqgcDTC',
#  '@sotcstill @OldDublinTown @LovinDublin @DublinTown @VisitDublin @dublin @deric_tv @TourismIreland @PictureIreland… https://t.co/98VF1BfGCm',
#  '@themetoffice @bbcweather just built a natural stone wall on the basis it was going to be dry today (as you guys sa… https://t.co/Mbcxf2IgJX',
#  '@therileyshot @BBCLookNorth @bbcweather @itvweather @LensAreLive @Liam_Ball92 @Welcome2Yorks Lovely photograph',
#  'A blustery afternoon at @NostellNT @JonMitchellITV @kerriegosneyTV @itvweather @Hudsonweather @KeeleyDonovan… https://t.co/U7EErMbDdZ',
#  'A bright, mild and windy day. Showers in the northwest, some rain developing in southern England. Winds strengthen… https://t.co/IByZz4C5te',
#  'A chilly sunset in ryhill park @JonMitchellITV @kerriegosneyTV @itvweather @metoffice @BBCWthrWatchers @bbcweather… https://t.co/3kHPFOj7W2',
#  'A powerful Jet Stream will propagate across the north Atlantic next week.\n\nStrong winds, gales, rain and wintry sho… https://t.co/dpuy63UoBJ',
#  'A sunny day at @StirUni this afternoon....until the wind picked up, blowing rain clouds over #Stirling (3/2)… https://t.co/nkyHmHar8d',
#  'A touch of brightness on a dull grey #MondayAfternoon at #Twickenham @metoffice  @bbcweather  @SallyWeather… https://t.co/eLXwcRbRQ4',
#  'After a sunny start around #Stirling winds blowing rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather… https://t.co/tOtpDgqBXF',
#  'As of 1300 GMT, we have seen the following temperatures today in France and Spain:\n\nSeillans 26.8C\nSantander airpor… https://t.co/feXKwJSRWT',
#  'Awesome mackerel clouds just now over #Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather @itvweather… https://t.co/eOZy9je83R',
#  'Como que 2/3? ya porfavorrr solo quiero ver el sol https://t.co/DdwNtd84TR',
#  "Cycling through Europe's deadliest air https://t.co/1gL5BK6HMt",
#  'Daffodils in Great Yarmouth @StormchaserUKEU @carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer… https://t.co/CZsW5g6Yyt',
#  'Does anyone else think it is rather fitting that the UK national anthem contains a pessimistic #weather forecast at… https://t.co/X9x7qo7aZs',
#  "Dry, hot summers could become 'norm' in Scotland https://t.co/8xgEL0uyYV",
#  'Early morning calm at Bushy Park #photooftheday  @theroyalparks @WildLondon @WWTLondon @StormHour @PhotoHour… https://t.co/WTwx3N1nAQ',
#  'Extraordinary temperatures being recorded today across France &amp; Spain. Again highlighting the extent &amp;widespread na… https://t.co/4zjuXQcvF5',
#  'Has spring arrived ? @ChrisPage90 @WeatherAisling @BBCWthrWatchers @bbcweather @StormHour @LensAreLive https://t.co/laSbcPcfWU',
#  'Holbeach Hurn #Lincolnshire\n@LincsSkies\n \n@EarthandClouds2 @StormHour @cloudymamma @BBCWthrWatchers @bbcweather… https://t.co/jgwD4okuNB',
#  'Holbeach Hurn #Lincolnshire\nStraight out of the camera. #sooc\n@LincsSkies\n \n@EarthandClouds2 @StormHour… https://t.co/jY5pgftA9R',
#  'I warned this would happen. @metoffice uses extremely high sensitivity HadGEM3-GA6 model, combined with recently de… https://t.co/kHK47JCiPY',
#  'It looks as if that jackdaw is making a contrail 😳🤣 Sunny spells are forecast for #Twickenham before a cloudy after… https://t.co/YrwBR88OX5',
#  'It was 9c and pouring when we were in Santander in June......ho hum https://t.co/9elLeHAq0u',
#  'Kirkwall bay, oh bonny Kirkwall bay... looking a bit lively tonight... https://t.co/Cqk6D2OOkT https://t.co/LM4nMCgQXw',
#  'Leg of Mutton Pond at Bushy Park #photooftheday  @theroyalparks @WildLondon @WWTLondon @StormHour @PhotoHour… https://t.co/pAhxZPkPRf',
#  'Milan car ban: Drivers ignore anti-pollution measure https://t.co/6BtAMWNfLP',
#  'Monday morning setting. @BBCNWT @bbcweather #Boothstown #Manchester #sunrise #sunrisephotography #colours https://t.co/M1Z6Zv5dHz',
#  'More local heat records tumbled in north on Monday\n\nMeanwhile, Milford Sound recorded almost 500mm (over a months w… https://t.co/Wur18q1ruY',
#  'Our partners @ultraleap pioneered this haptic technology. Could it be the future of out weather forecasts? Great ex… https://t.co/TK5EHYIsVE',
#  'Porthleven 2014 the year the inner harbour baulks were smashed apart and lots of boats sunk/damaged… https://t.co/O14qq5QACO',
#  'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland @bbcweather…',
#  'RT @DerekTheWeather: A powerful Jet Stream will propagate across the north Atlantic next week.\n\nStrong winds, gales, rain and wintry shower…',
#  'RT @GWestCBayCC: #Greenock #Gourock #Inverclyde #Scotland #WeatherAware https://t.co/ueMAxvkj4l',
#  'RT @GeordieCanary: Has spring arrived ? @ChrisPage90 @WeatherAisling @BBCWthrWatchers @bbcweather @StormHour @LensAreLive https://t.co/laSb…',
#  'RT @Iceman26061: Lovely pink clouds from yesterday🌅☁️ #clouds #sunset #weather #photography #Northamptonshire #loveukweather @LensAreLive @…',
#  'RT @Ichabodus: Holbeach Hurn #Lincolnshire\n@LincsSkies\n \n@EarthandClouds2 @StormHour @cloudymamma @BBCWthrWatchers @bbcweather @spaldingtod…',
#  'RT @Ichabodus: Holbeach Hurn #Lincolnshire\nStraight out of the camera. #sooc\n@LincsSkies\n \n@EarthandClouds2 @StormHour @cloudymamma @BBCWth…',
#  'RT @JaneDryden4: I warned this would happen. @metoffice uses extremely high sensitivity HadGEM3-GA6 model, combined with recently debunked…',
#  'RT @KimGPhoto: Stormy seas surrounding the Isle of Skye today 🌊\n\n@VisitScotland @bbcweather #isleofskye #Scotland #Weather #ScotlandIsNow h…',
#  'RT @MetMattTaylor: More local heat records tumbled in north on Monday\n\nMeanwhile, Milford Sound recorded almost 500mm (over a months worth…',
#  'RT @StiofanNutty: Extraordinary temperatures being recorded today across France &amp; Spain. Again highlighting the extent &amp;widespread nature o…',
#  'RT @absolutoursuk: #Mevagissey meanders on a #winter afternoon.#fishinglife @ILoveCornwallUK @VisitSWEngland @WhatsonSW @cornwallfilming @C…',
#  'RT @bbcweather: A bright, mild and windy day. Showers in the northwest, some rain developing in southern England. Winds strengthen with gus…',
#  'RT @bbcweather: A day of #summer extremes in New Zealand on Sunday.\n\nWhilst Napier, on North Island, experienced its #hottestdayonrecord at…',
#  'RT @bbcweather: AUSTRALIA: New South Wales and ACT experienced the worst of the #heatwave on Saturday\n\nCanberra had its hottest day on reco…',
#  'RT @bbcweather: Feeling the forecast through haptic technology. Could this be the future of BBC Weather?\nhttps://t.co/u9w2K98EL7 https://t.…',
#  'RT @bbcweather: Gales across Scotland later tomorrow. Gusts of 60-70mph for northern &amp; western Scotland and up to 80mph for the Western Isl…',
#  'RT @bbcweather: Major motorway closed and residents in Canberra region told to seek shelter from out of control bushfires. Hot and windy co…',
#  'RT @bbcweather: We are two thirds of the way through meteorological winter and some UK locations, including Kirkwall (Orkney), Weybourne (N…',
#  'RT @chris_alpacas: A grey day at the river side in St Ives, Cambridgeshire @metoffice @ChrisPage90 @WeatherAisling @itvanglia @bbcweather @…',
#  'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n\n@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather @barrabest @Disco…',
#  'RT @every_station: The cloud formations just now at Gretna Green are amazing! 156507 on a Carlisle to Glasgow Central service. \n\n@ScotRail…',
#  'RT @frasergj: A sunny day at @StirUni this afternoon....until the wind picked up, blowing rain clouds over #Stirling (3/2) #WeatherWatcherG…',
#  'RT @frasergj: After a sunny start around #Stirling winds blowing rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather @BBCAimsir…',
#  'RT @gazza_d: This is fine https://t.co/76CdECe4al',
#  'RT @highland_andy: This image has to be viewed large to be appreciated.\nTaken at 1/80th of a second to bigger the snow a hint of blur.\n#red…',
#  'RT @ruths_gallery: A touch of brightness on a dull grey #MondayAfternoon at #Twickenham @metoffice  @bbcweather  @SallyWeather @itvweather…',
#  'RT @ruths_gallery: Awesome mackerel clouds just now over #Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather @itvweather @Clo…',
#  'RT @ruths_gallery: It looks as if that jackdaw is making a contrail 😳🤣 Sunny spells are forecast for #Twickenham before a cloudy afternoon…',
#  'RT @ruths_gallery: ‘I’m watching you’.  A jackdaw on our balcony on a cloudy afternoon at #Twickenham @metoffice  @bbcweather  @SallyWeathe…',
#  'RT @secrethighlands: Not seen the falls so full of water before! Amazing!!#secrethighlands \n#SaturdayMotivation #SaturdayMorning #waterfall…',
#  'RT @simon_weather: Daffodils in Great Yarmouth @StormchaserUKEU @carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer @iainG81 @Me…',
#  'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU @carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer @iainG81 @MetR…',
#  'RT @therileyshot: Some nice colours this morning whilst I have my morning breakfast battle with the little munchkin! Have a fab week everyo…',
#  'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️',
#  'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️ https://t.co/Nphu3hJVQa',
#  'RT ultraleap "We spot an ultraleap mid-air #haptic array! 👀🌦️ https://t.co/ribK44J5Gj"',
#  'Serbia (deep ties to Russia)👉 country with the highest rate of pollution-related deaths in Europe, according to the… https://t.co/esdpkPZbhY',
#  'Some nice colours this morning whilst I have my morning breakfast battle with the little munchkin! Have a fab week… https://t.co/qnCajuANja',
#  'Stormy seas surrounding the Isle of Skye today 🌊\n\n@VisitScotland @bbcweather #isleofskye #Scotland #Weather… https://t.co/dbsYA9rKTP',
#  'Sunrise in Great Yarmouth @StormchaserUKEU @carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer @iainG81… https://t.co/RNatAcYBDn',
#  'Sunshine, rain or snow. For me all of the enjoyment of the weather comes from how it feels. ☀️ 🌧 ❄️ https://t.co/fUOgmvCdlJ',
#  'Take care on the roads in Scotland today. https://t.co/0sCqsmZysI',
#  "The BBC's haptic weather forecast machine lets you feel the weather\n#BBCWeather #WeatherForecast @BBCNews… https://t.co/bdKLimhKjc",
#  'The cloud formations just now at Gretna Green are amazing! 156507 on a Carlisle to Glasgow Central service.… https://t.co/MILaurBXdM',
#  'This IS not normal #10 https://t.co/vRyhmr4PbV',
#  'This image has to be viewed large to be appreciated.\nTaken at 1/80th of a second to bigger the snow a hint of blur.… https://t.co/ltBfN1nz7c',
#  'This is fine https://t.co/76CdECe4al',
#  'We are two thirds of the way through meteorological winter and some UK locations, including Kirkwall (Orkney), Weyb… https://t.co/X7skB5rYxV',
#  'We spot an @ultraleap mid-air #haptic array! 👀🌦️ https://t.co/Nphu3hJVQa',
#  'Wicklow Harbour, Ireland\n@visitwicklow @WicklowTownTeam  @Welcome2Wicklow @WicklowThisWeek @PictureIreland… https://t.co/oSIZvAntbG',
#  'thisisfine.jpg https://t.co/MGIQvFLKmB',
#  '‘I’m watching you’.  A jackdaw on our balcony on a cloudy afternoon at #Twickenham @metoffice  @bbcweather… https://t.co/ygjqFDk1Gg']

# %%
#find distinct user names
#db.weather.distinct("user.name")
wcol.distinct("user.name")
# Out:
# ['#StormHour',
#  '#ThePhotoHour',
#  'Abha Paulina',
#  'Adam Withey',
#  'Adie',
#  'Al Hine',
#  'Alex Hynes',
#  'Alex Mulcrow',
#  'Andy Howard',
#  'Angee Kinniyos',
#  'Ayub Zumla',
#  'BBC Highlands',
#  'BBC Scotland News',
#  'BBC Scotland Weather',
#  'BBC Weather',
#  'Barbara Anne Lawhead',
#  'Belencius',
#  'Big Dave',
#  'Blind Harper',
#  'Blush Marnie',
#  'Bob Sharples',
#  'Bristol Digital Futures Institute',
#  'Callum⚽️',
#  'Cameron Lodges',
#  'Carole Esq.’ess ✝️🇬🇧🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f',
#  'Carole✝️🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🇬🇧',
#  'Carsten Pe',
#  'Chloé',
#  'Chris',
#  'Chris Caseldine',
#  'Chris Townsend',
#  'Christine Mitchell',
#  'Chuck Dalldorf',
#  'ClimateKola',
#  'Corrie and Co',
#  'Craig Parkinson',
#  'DK',
#  'Dave',
#  'Dave Montgomery',
#  'DaveThingy',
#  'David Proudlock',
#  'Dee',
#  'Dj_b [GAWA]',
#  "Dorothy O'Brien",
#  'Eduardo Jiménez',
#  'Edward Vanderpump',
#  'El Libro de Maat.(Silvia)',
#  'Elizabeth B',
#  'Elizabeth FITZPATRIC',
#  'Emma Morris',
#  'Every Last Station',
#  'Fitba Mad',
#  'Gavin Daly',
#  'Gerard Alexander',
#  'Gizmodo UK',
#  'Goodie',
#  'Graham C. Maloney',
#  'Graham Fraser',
#  'Grant McKenzie',
#  'Helen Crump',
#  'Iceman2606',
#  'Ichabod',
#  'Immersiversity',
#  'Into Cornwall',
#  'InvernessLochNess',
#  'Jae',
#  'James',
#  'Jay',
#  "Je m'appelle F",
#  'Jean Dorothy Pedder',
#  'Jeanne Hoffa',
#  'Jennifer Ashlin',
#  'Jim Foster',
#  'Jim McKeown',
#  'Jim The Poet',
#  'Joanne Fraser',
#  'Joel',
#  'John Hunter',
#  'Johnny Posh',
#  'Jude Price',
#  'Judy Hockenbrough',
#  'KarlOnSea',
#  'Kate Vause',
#  'Kathy Levine',
#  'Kim Grant',
#  'Kim Harding',
#  'LD Perennis',
#  'Lana Preston',
#  'Let Dogs Be Dogs',
#  'Lisa von Steijern',
#  'Liz Elliott',
#  'Llwybr Arfordir Cymru / Wales Coast Path',
#  'Looking Glass Factory',
#  'Lori Adams',
#  'Lorna Robertson',
#  'Luke',
#  'Lupine Adventure Co-op 🧗\u200d♀️🏔️',
#  'Marc Yves',
#  'Maria Wagner',
#  'Martin Finch',
#  'Matt Taylor',
#  'Maureen',
#  'Maurice Thomas',
#  'Michael J. Prior',
#  'Mike Armstrong 🇪🇺🌍🦋',
#  'Miri',
#  'MonicaOP♥️🌎✝️🌼',
#  'Nick Crew',
#  'Nick purcell',
#  'Nikki de Villiers',
#  'Norman Fucking Rockwell',
#  'Norman Kerr OBE',
#  'Oak Tree HA',
#  'Official Weather UK ❄️',
#  'Oliver Rendall',
#  'Orestis Georgiou',
#  'OurFuture - BOT',
#  'PABHERE',
#  'PGS Services',
#  'Paolo Saracino',
#  'Patricia Stoughton',
#  'Paul Scanlon 🏃\u200d♂️🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🏃🎖',
#  'Paul lambert',
#  'Peter Gibbs',
#  'Port Glasgow West CC',
#  'Priscila',
#  'Real Gaz of Trumpton #fbpe',
#  'Ross Donaldson',
#  'Ruth Holmes',
#  'Ruth Wadey',
#  'STEVE DAVEY',
#  'Sam Williams',
#  'Samanthalouise',
#  'Sara Diana Williams',
#  'Severe thunderstorms',
#  'Shane Ryland',
#  'Silvie Krebs',
#  "Simon's Weather Photography",
#  'Sophie Kervella de Joannis 🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#  'Spaceships Rentals UK & Europe',
#  'Stephen Gorman',
#  'Sterntendo',
#  'Steve Payne Ⓥ 🌹✡',
#  'Stiofán Nutty',
#  'Stirling Holiday',
#  'Stirling Man',
#  'Stone Art Gallery',
#  'Strawberry Hill GC',
#  'Stuart Neilly 🇬🇧🇨🇦🇹🇭',
#  'Sue Billcliffe',
#  'Talking Glasgow',
#  'The Led Zeppelin Curse',
#  'The Picture Poet',
#  'The Riley Shot Photography (Scott for short 😀)',
#  'The Wanderer.... Marydoll',
#  'Tiger II',
#  'Tim Lennon',
#  'Tim Rayner',
#  'Tom Carter',
#  'Transport_FanUk/SalemAndCookie',
#  'Travel with Flower',
#  'Ultraleap',
#  'Veles 🇭🇰',
#  'Wales Propertyfinder',
#  'Wayfarer',
#  'Wayne Williams',
#  'Weather Updates',
#  'Wendy',
#  "What's On Southwest Magazine Est: 1996",
#  'Will Clapp',
#  'Yeohan Kim',
#  'angie phillips',
#  'angus.',
#  'ashley',
#  'elanor 🍃💚🍃',
#  'hanna christine',
#  'ignis fatuus',
#  'j',
#  'last train 🇬🇧🇪🇺🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f🕎',
#  'nababuckskskd. boom',
#  'neverforgettea',
#  'noël',
#  'owen williams',
#  'phil ashley',
#  'realSteveSchindler.',
#  'ricitos.mcr',
#  'rockyhud',
#  'stuart Scarisbrick #FBPE Rejoin 🇪🇺',
#  'svenc',
#  'tasha charles',
#  'weather pictures',
#  'ᴅᴇʀᴇᴋ ʙʀᴏᴄᴋᴡᴀʏ ᴡᴇᴀᴛʜᴇʀᴍᴀɴ',
#  'ℭ𝔥𝔯𝔦𝔰 𝔅𝔢𝔞𝔠𝔥',
#  '⚡☔🌩 Simon L ❄⛄🌨',
#  'じゅん 2/19 XRミーティング札幌進行役 3/9倉敷でセミナー',
#  '🌗🌍 MrsC 🌎🌓',
#  '🍀MMyLife✨',
#  '🐶🐾TOBY CAIRN TERRIER 🐾🐶']

# %%
# find the distinct media types
# db.weather.distinct("extended_entities.media.type")
wcol.distinct("extended_entities.media.type")
# Out:
# ['animated_gif', 'photo', 'video']

# %% [markdown]
# 6. Print Functions

# %%
#Function to interate through the tweets found
def printTweets(tweetSet):
    for tweet in tweetSet:
        pprint(tweet)

#Function tp print the results from update queries
def printResult(result):
    print ("Match count: ", result.matched_count)
    print ("Modified count: ", result.modified_count)
    print (type(result))

# %%
# db.weather.find({"user.name":"BBC Highlands"}, {id: 1, _id:0}).pretty()
# Syntax difference: attribute names must be in quotes
tweets = wcol.find({"user.name": "BBC Highlands"}, {"id": 1, "_id" : 0})

#Call the print tweets function
printTweets(tweets)
# Out:
# {'id': 1224222678682349570}

# %% [markdown]
# 7. Pattern Matching

# %%
#Search for "sun"
#db.weather.find({text: "sun"})

tweets = wcol.find({"text": "sun"})
printTweets(tweets)

# %%
# db.weather.find({text: /sun/}).count()
# Syntax difference: this form of pattern matching will not work in Python
# You have to use the $regex syntax instead.

tweets = wcol.find({'text':{'$regex':'sun'}}, {'text': 1})
printTweets(tweets)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4c'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e58'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5f'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e64'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e68'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6e'),
#  'text': 'A chilly sunset in ryhill park @JonMitchellITV @kerriegosneyTV '
#          '@itvweather @metoffice @BBCWthrWatchers @bbcweather… '
#          'https://t.co/3kHPFOj7W2'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e70'),
#  'text': 'A sunny day at @StirUni this afternoon....until the wind picked up, '
#          'blowing rain clouds over #Stirling (3/2)… https://t.co/nkyHmHar8d'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e72'),
#  'text': '#sunset over #m6n #rushhour @bbcmtd @bbcweather Birmingham '
#          'https://t.co/xfmiSqR0u3'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea0'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea4'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed2'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed4'),
#  'text': 'After a sunny start around #Stirling winds blowing rain clouds '
#          'across (3/2) #WeatherWatcherGraham @BBCScotWeather… '
#          'https://t.co/tOtpDgqBXF'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed9'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f17'),
#  'text': 'RT @Iceman26061: Lovely pink clouds from yesterday🌅☁️ #clouds '
#          '#sunset #weather #photography #Northamptonshire #loveukweather '
#          '@LensAreLive @…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1a'),
#  'text': 'Porthleven 2014 the year the inner harbour baulks were smashed apart '
#          'and lots of boats sunk/damaged… https://t.co/O14qq5QACO'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f28'),
#  'text': 'Monday morning setting. @BBCNWT @bbcweather #Boothstown #Manchester '
#          '#sunrise #sunrisephotography #colours https://t.co/M1Z6Zv5dHz'}

# %%
# db.weather.find({ text: { $regex: /sun/i } }).count()
# If you want to make the search case insensitive, you have to use $options␣ ↪with $regex:

tweets = wcol.find({'text':{'$regex':'sun', '$options': 'i'}}, {'text': 1})
printTweets(tweets)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4c'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e58'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5f'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e64'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e67'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e68'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6e'),
#  'text': 'A chilly sunset in ryhill park @JonMitchellITV @kerriegosneyTV '
#          '@itvweather @metoffice @BBCWthrWatchers @bbcweather… '
#          'https://t.co/3kHPFOj7W2'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e70'),
#  'text': 'A sunny day at @StirUni this afternoon....until the wind picked up, '
#          'blowing rain clouds over #Stirling (3/2)… https://t.co/nkyHmHar8d'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e72'),
#  'text': '#sunset over #m6n #rushhour @bbcmtd @bbcweather Birmingham '
#          'https://t.co/xfmiSqR0u3'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea0'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea4'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eab'),
#  'text': 'Sunshine, rain or snow. For me all of the enjoyment of the weather '
#          'comes from how it feels. ☀️ 🌧 ❄️ https://t.co/fUOgmvCdlJ'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebc'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eca'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed2'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed4'),
#  'text': 'After a sunny start around #Stirling winds blowing rain clouds '
#          'across (3/2) #WeatherWatcherGraham @BBCScotWeather… '
#          'https://t.co/tOtpDgqBXF'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed5'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed9'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902edb'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee6'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee9'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f00'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f03'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0a'),
#  'text': 'RT @bbcweather: A day of #summer extremes in New Zealand on Sunday.\n'
#          '\n'
#          'Whilst Napier, on North Island, experienced its #hottestdayonrecord '
#          'at…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0d'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f13'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f14'),
#  'text': 'It looks as if that jackdaw is making a contrail 😳🤣 Sunny spells are '
#          'forecast for #Twickenham before a cloudy after… '
#          'https://t.co/YrwBR88OX5'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f17'),
#  'text': 'RT @Iceman26061: Lovely pink clouds from yesterday🌅☁️ #clouds '
#          '#sunset #weather #photography #Northamptonshire #loveukweather '
#          '@LensAreLive @…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f18'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1a'),
#  'text': 'Porthleven 2014 the year the inner harbour baulks were smashed apart '
#          'and lots of boats sunk/damaged… https://t.co/O14qq5QACO'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1c'),
#  'text': 'Sunrise in Great Yarmouth @StormchaserUKEU @carlharlott @danholley '
#          '@stormbell @Lowweather @TheSnowDreamer @iainG81… '
#          'https://t.co/RNatAcYBDn'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1f'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f28'),
#  'text': 'Monday morning setting. @BBCNWT @bbcweather #Boothstown #Manchester '
#          '#sunrise #sunrisephotography #colours https://t.co/M1Z6Zv5dHz'}

# %%
# db.weather.find({text: /rain/}).count()
# Syntax difference: count() is depreciated.
# Use count_documents instead, which can take a Regular Expression (or any␣
   #↪query) as a parameter.
wcol.count_documents({'text':{'$regex':'rain'}})
# Out:
# 36

# %%
#Find tweets ending in snow
# db.weather.find({ text: { $regex: /snow$/i } })
wcol.count_documents({'tect': {'$regex': 'snow$', '$options': 'i'}})
# Out:
# 0

# %%
#db.weather.find({ text: { $in: [/^sun/i, /rain/] } }).count()
#wcol.count_documents({'text': { '$in': ['$regex': 'sun']}})
# Use of $in is less obvious and needs use of the re (regular expression␣
              #↪)library

tweets = wcol.find({'text': {'$in': [re.compile('.*sun.*'), re.compile('.*rain.*')]}}, {'text' : 1})
printTweets(tweets)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3e'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3f'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e44'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e46'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4a'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4c'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4d'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e51'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e53'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e54'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e55'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e56'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e57'),
#  'text': 'A powerful Jet Stream will propagate across the north Atlantic next '
#          'week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry sho… https://t.co/dpuy63UoBJ'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e58'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e59'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5f'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e64'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e68'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6e'),
#  'text': 'A chilly sunset in ryhill park @JonMitchellITV @kerriegosneyTV '
#          '@itvweather @metoffice @BBCWthrWatchers @bbcweather… '
#          'https://t.co/3kHPFOj7W2'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e70'),
#  'text': 'A sunny day at @StirUni this afternoon....until the wind picked up, '
#          'blowing rain clouds over #Stirling (3/2)… https://t.co/nkyHmHar8d'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e72'),
#  'text': '#sunset over #m6n #rushhour @bbcmtd @bbcweather Birmingham '
#          'https://t.co/xfmiSqR0u3'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9a'),
#  'text': '@every_station @ScotRail @AlexHynes @bbcweather I saw that train at '
#          'Carsile about 30 minutes ago, I’m on an avanti… '
#          'https://t.co/IJsjzTb25C'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea0'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea4'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eab'),
#  'text': 'Sunshine, rain or snow. For me all of the enjoyment of the weather '
#          'comes from how it feels. ☀️ 🌧 ❄️ https://t.co/fUOgmvCdlJ'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecc'),
#  'text': '@Silligilli @porridgebrain @cairnstoon @bbcweather'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecd'),
#  'text': '@YorkshireBird_ @porridgebrain @LevParikian @bbcweather'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed2'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed4'),
#  'text': 'After a sunny start around #Stirling winds blowing rain clouds '
#          'across (3/2) #WeatherWatcherGraham @BBCScotWeather… '
#          'https://t.co/tOtpDgqBXF'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed9'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0c'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f17'),
#  'text': 'RT @Iceman26061: Lovely pink clouds from yesterday🌅☁️ #clouds '
#          '#sunset #weather #photography #Northamptonshire #loveukweather '
#          '@LensAreLive @…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1a'),
#  'text': 'Porthleven 2014 the year the inner harbour baulks were smashed apart '
#          'and lots of boats sunk/damaged… https://t.co/O14qq5QACO'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f25'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f26'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f28'),
#  'text': 'Monday morning setting. @BBCNWT @bbcweather #Boothstown #Manchester '
#          '#sunrise #sunrisephotography #colours https://t.co/M1Z6Zv5dHz'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f29'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2b'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2e'),
#  'text': 'A bright, mild and windy day. Showers in the northwest, some rain '
#          'developing in southern England. Winds strengthen… '
#          'https://t.co/IByZz4C5te'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f30'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f33'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…'}

# %% [markdown]
# 8. Further Queries
# The following shows examples of: - operators - handling null and boolean data - aggregation

# %%
# db.weather.find({"retweeted_status.retweet_count": { $gt : 20 }}).count()
# Syntax difference: $gt must be in quotes

wcol.count_documents({"retweeted_status.retweet_count": {'$gt': 20}})
# Out:
# 32

# %%
# db.weather.find({"user.location": { $eq : null }}).count()
# Syntax difference: $eq must be in quotes and null is represented by the␣
    #↪singleton None
wcol.count_documents( {"user.location": { '$eq' : None }})
# Out:
# 0

# %%
# db.weather.find({"user.geo_enabled": { $eq : true }}).count()
# Syntax difference: true is represented by True

wcol.count_documents( {"user.geo_enabled": {'$eq' : True }})
# Out:
# 130

# %%
# db.weather.find({"user.followers_count": { $lte : 10 }}).count()
# Syntax difference: $lte must be in quotes

wcol.count_documents( {"user.followers_count": { '$lte' : 10 }})
# Out:
# 6

# %%
# GROUP BY command and aggregation
#db.weather.aggregate( [ {
#     $group: {
#        _id : null,
#        totalAmount: { $sum: "$retweeted_status.retweet_count" },
#        count: { $sum: 1 }
# } } ] )

# Syntax difference: all the parameters must be in quotes
grpBy = wcol.aggregate( [
{
    '$group': {
        '_id' : None,
        'totalAmount': { '$sum': "$retweeted_status.retweet_count" },
        'count': { '$sum': 1 }
    }
}
] )
printTweets(grpBy)
# Out:
# {'_id': None, 'count': 250, 'totalAmount': 2221}

# %% [markdown]
# 9. Cleaning Data
# (Let’s change one of the languages to the full name.)

# %%
wcol.distinct("lang")
# Out:
# ['English', 'en', 'es', 'unknown']

# %%
# You need to find the ObjectIds in your data
# For example, es is Spanish
#db.weather.find({ lang: "es"}, {lang:1})

langs = wcol.find({ 'lang': "Replace_this_with_a_language_code"}, {'lang':1})
printTweets(langs)

# %%
myObjectId = '67e602a8d90ddd6ec2902e3e'

# %%
# update One record to change the User's lanuage to the full name
# db.weather.find ({ _id: ObjectId("myObjectID")}, {lang: 1}).pretty()
# check the record first:
tweet = wcol.find( { '_id': ObjectId(myObjectId)}, {'lang':1} )
printTweets(tweet)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3e'), 'lang': 'English'}

# %%
# Replace with the full language, for example, to replace es with Spanish would␣ ↪be:
#db.weather.update({ _id: ObjectId("myObjectID") }, {$set: {'lang':␣ ↪'Spanish'}})

# Syntax difference: update command is depreciated in Python.
# Need to use either: update_one, replace_one or update_many

updateResult = wcol.update_one({ '_id': ObjectId(myObjectId) }, {'$set': {'lang': 'English'}})
printResult(updateResult)
# Out:
# Match count:  1
# Modified count:  0
# <class 'pymongo.results.UpdateResult'>

# %%
# Check if updated:
tweet= wcol.find( { '_id': ObjectId(myObjectId)}, {'lang':1} )
printTweets(tweet)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3e'), 'lang': 'English'}

# %%
# Change documents where the language is undecided (und) to say unknown:
updateResult = wcol.update_many({ 'lang': "und" }, {'$set': {'lang': 'unknown'}})
printResult(updateResult)
# Out:
# Match count:  0
# Modified count:  0
# <class 'pymongo.results.UpdateResult'>

# %%
# Want all the English locations to just say UK
tweets = wcol.find( { 'user.location': {'$regex':'England','$options': 'i'}},{'user.location':1, '_id':0} )
printTweets(tweets)

# %%
# db.weather.updateMany({ 'user.location': {$regex:'England',$options: 'i' }} , {$set: {'user.location': 'UK'}})
# Syntax difference: update updateMany() is replaced by update_many()
# Note: there is no option to ROLLBACK the update!
updateResult = wcol.update_many({ 'user.location': {'$regex': 'England','$options': 'i' }} , {'$set': {'user.location': 'UK'}})
printResult(updateResult)
# Out:
# Match count:  0
# Modified count:  0
# <class 'pymongo.results.UpdateResult'>

# %%
# Check if updated:
tweets = wcol.find( { 'user.location': {'$regex':'UK','$options': 'i' }},{'user.location':1, '_id':0} )
printTweets(tweets)
# Out:
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Wales UK'}}
# {'user': {'location': 'Uk, Doncaster, South Yorkshire'}}
# {'user': {'location': 'Barrybados-Cardiff-Cymru-UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Surrey UK '}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': '#DearneValley S.Yorkshire - UK'}}
# {'user': {'location': 'Bristol UK'}}
# {'user': {'location': 'Cornwall, UK'}}
# {'user': {'location': 'On a bike, somewhere in the UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Northamptonshire, UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Bristol UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'uk'}}
# {'user': {'location': 'Strawberry Hill, Twickenham,UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Norwich, Norfolk, UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'London, UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'Manchester,UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}
# {'user': {'location': 'UK'}}

# %% [markdown]
# 10. Reshaping the Data
# 10.1. Reduce the number of columns

# %%
# Reduce the number of columns in a collection
# Creating a new collection with just 2 selected fields: user.location and the text.
"""db.weather.aggregate([
      {$project:{"user.location":1, text:1}},
       {$out:"projWeather"}
   ])
"""
# Syntax difference: the various parameters must be in quotes
wcol.aggregate([
    {'$project': {'user.location': 1, 'text': 1}},
    {'$out': "projWeather"}
])

# %%
# Check that the new collection exists with the required data:
# db.newWeather.find().pretty()

# Create a variable called newcol to hold the new collection
projcol = mydb["projWeather"]
newData = (projcol.find({}))
printTweets(newData)
# Out:
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3a'),
#  'text': '@Lillybetmax @VisitCairngrms @VisitScotland @ScotsMagazine '
#          '@BBCSpringwatch @uknationalparks @bbcweather @metoffice… '
#          'https://t.co/NcYieNDbRs',
#  'user': {'location': 'Highlands of Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3b'),
#  'text': 'Como que 2/3? ya porfavorrr solo quiero ver el sol '
#          'https://t.co/DdwNtd84TR',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3c'),
#  'text': 'RT @highland_andy: This image has to be viewed large to be '
#          'appreciated.\n'
#          'Taken at 1/80th of a second to bigger the snow a hint of blur.\n'
#          '#red…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3d'),
#  'text': 'RT @therileyshot: Some nice colours this morning whilst I have my '
#          'morning breakfast battle with the little munchkin! Have a fab week '
#          'everyo…',
#  'user': {'location': 'Utah'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3e'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e3f'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e40'),
#  'text': '@owz09 @DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales 😁',
#  'user': {'location': 'Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e41'),
#  'text': '@highland_andy @VisitCairngrms @VisitScotland @ScotsMagazine '
#          '@BBCSpringwatch @uknationalparks @bbcweather… '
#          'https://t.co/rblo0HfOC5',
#  'user': {'location': "God's Own County "}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e42'),
#  'text': '@WAWilliams15 @DerekTheWeather @bbcweather @BBCWalesToday '
#          '@BBCRadioWales ISO bars? Are they protein bars, they sound nice 😋 😉',
#  'user': {'location': 'Ammanford,wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e43'),
#  'text': '@highland_andy @VisitCairngrms @VisitScotland @ScotsMagazine '
#          '@BBCSpringwatch @uknationalparks @bbcweather… '
#          'https://t.co/OAc67eH24Q',
#  'user': {'location': 'Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e44'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e45'),
#  'text': '@SGIRE82 @VisitCairngrms @VisitScotland @ScotsMagazine '
#          '@BBCSpringwatch @uknationalparks @bbcweather @metoffice @BBCEarth '
#          '@BBCOutofDoors 🙏😊👍',
#  'user': {'location': 'Highlands of Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e46'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Swansea, Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e47'),
#  'text': 'This image has to be viewed large to be appreciated.\n'
#          'Taken at 1/80th of a second to bigger the snow a hint of blur.… '
#          'https://t.co/ltBfN1nz7c',
#  'user': {'location': 'Highlands of Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e48'),
#  'text': '@bbcweather https://t.co/7fIC2ysZCD',
#  'user': {'location': 'Brooklyn, NY'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e49'),
#  'text': 'RT @highland_andy: This image has to be viewed large to be '
#          'appreciated.\n'
#          'Taken at 1/80th of a second to bigger the snow a hint of blur.\n'
#          '#red…',
#  'user': {'location': 'Cairngorms'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4a'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4b'),
#  'text': '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Maybe get '
#          'a chance to put the winter tyres to test....at last ☃️🤔😂',
#  'user': {'location': 'Hawarden, Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4c'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4d'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Pembrokeshire'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4e'),
#  'text': '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Ooohhj ! '
#          'Severe wind 😮',
#  'user': {'location': 'Wales UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e4f'),
#  'text': '@sotcstill @OldDublinTown @LovinDublin @DublinTown @VisitDublin '
#          '@dublin @deric_tv @TourismIreland @PictureIreland… '
#          'https://t.co/98VF1BfGCm',
#  'user': {'location': 'Wicklow, Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e50'),
#  'text': '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Oh dear! '
#          'No sign of a cold snap then ? ❄️☃️',
#  'user': {'location': 'Llanmadoc'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e51'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'West Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e52'),
#  'text': '@DerekTheWeather @bbcweather @BBCWalesToday @BBCRadioWales Those iso '
#          'bars are quite close 😱',
#  'user': {'location': 'Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e53'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e54'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Wales, United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e55'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': '🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e56'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Uk, Doncaster, South Yorkshire'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e57'),
#  'text': 'A powerful Jet Stream will propagate across the north Atlantic next '
#          'week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry sho… https://t.co/dpuy63UoBJ',
#  'user': {'location': 'Barrybados-Cardiff-Cymru-UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e58'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…',
#  'user': {'location': 'Central Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e59'),
#  'text': 'RT @DerekTheWeather: A powerful Jet Stream will propagate across the '
#          'north Atlantic next week.\n'
#          '\n'
#          'Strong winds, gales, rain and wintry shower…',
#  'user': {'location': 'Cardiff, Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5a'),
#  'text': 'Wicklow Harbour, Ireland\n'
#          '@visitwicklow @WicklowTownTeam  @Welcome2Wicklow @WicklowThisWeek '
#          '@PictureIreland… https://t.co/oSIZvAntbG',
#  'user': {'location': 'Wicklow, Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5b'),
#  'text': '@hugysmum @metoffice @bbcweather @SallyWeather @itvweather '
#          '@SimonOKing @StormHour @ThePhotoHour 🦅',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5c'),
#  'text': '@hugysmum @metoffice @bbcweather @SallyWeather @itvweather '
#          '@SimonOKing @StormHour @ThePhotoHour It’s a bird! Thank… '
#          'https://t.co/FTkAGboel2',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5d'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Port Glasgow Inverclyde'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5e'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e5f'),
#  'text': 'RT @frasergj: A sunny day at @StirUni this afternoon....until the '
#          'wind picked up, blowing rain clouds over #Stirling (3/2) '
#          '#WeatherWatcherG…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e60'),
#  'text': '@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather '
#          '@SimonOKing @StormHour @ThePhotoHour 😱😱😱😱',
#  'user': {'location': 'Belfast, Northern Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e61'),
#  'text': '@lana_preston @StirUni @BBCScotWeather @BBCAimsir @bbcweather '
#          '@metoffice @BBCWthrWatchers @BBCCountryfile @BBCEarth… '
#          'https://t.co/48dWvHyDcT',
#  'user': {'location': 'Stirling, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e62'),
#  'text': 'A blustery afternoon at @NostellNT @JonMitchellITV @kerriegosneyTV '
#          '@itvweather @Hudsonweather @KeeleyDonovan… https://t.co/U7EErMbDdZ',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e63'),
#  'text': 'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch '
#          'Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland '
#          '@bbcweather…',
#  'user': {'location': 'Surrey UK '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e64'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e65'),
#  'text': '@AnjanaGadgil @Kate_Kinsella @BrownieLB_1 @SallyTaylor_tv '
#          '@BBCWeather @BBCSWWeather @karenjane16ka @KeeleyDonovan… '
#          'https://t.co/AD6We1sEct',
#  'user': {'location': 'Blackwood, Wales'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e66'),
#  'text': '@bbcweather has done me dirty today, light showers? What a load of '
#          'crap',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e67'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e68'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e69'),
#  'text': '@bbcpointswest @bbcweather Portishead Marina https://t.co/5VDnw5Jf8x',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6a'),
#  'text': '@bbcweather 27 degrees across Northwest Italy too.',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6b'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Hemel Hempstead, East'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6c'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6d'),
#  'text': 'RT @secrethighlands: Not seen the falls so full of water before! '
#          'Amazing!!#secrethighlands \n'
#          '#SaturdayMotivation #SaturdayMorning #waterfall…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6e'),
#  'text': 'A chilly sunset in ryhill park @JonMitchellITV @kerriegosneyTV '
#          '@itvweather @metoffice @BBCWthrWatchers @bbcweather… '
#          'https://t.co/3kHPFOj7W2',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e6f'),
#  'text': '@frasergj @StirUni @BBCScotWeather @BBCAimsir @bbcweather @metoffice '
#          '@BBCWthrWatchers @BBCCountryfile @BBCEarth… https://t.co/G10xHKL07y',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e70'),
#  'text': 'A sunny day at @StirUni this afternoon....until the wind picked up, '
#          'blowing rain clouds over #Stirling (3/2)… https://t.co/nkyHmHar8d',
#  'user': {'location': 'Stirling, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e71'),
#  'text': 'RT @ruths_gallery: A touch of brightness on a dull grey '
#          '#MondayAfternoon at #Twickenham @metoffice  @bbcweather  '
#          '@SallyWeather @itvweather…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e72'),
#  'text': '#sunset over #m6n #rushhour @bbcmtd @bbcweather Birmingham '
#          'https://t.co/xfmiSqR0u3',
#  'user': {'location': 'Coventry, West Midlands'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e73'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e74'),
#  'text': '@bbcweather The ocean always helps lol.',
#  'user': {'location': 'Dungeon Master '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e75'),
#  'text': "The BBC's haptic weather forecast machine lets you feel the weather\n"
#          '#BBCWeather #WeatherForecast @BBCNews… https://t.co/bdKLimhKjc',
#  'user': {'location': 'London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e76'),
#  'text': '@bbcweather Beautiful day to be had by everyone there then!',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e77'),
#  'text': 'RT @chris_alpacas: A grey day at the river side in St Ives, '
#          'Cambridgeshire @metoffice @ChrisPage90 @WeatherAisling @itvanglia '
#          '@bbcweather @…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e78'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e79'),
#  'text': '@bbcweather @BBCScotWeather We have some fairly brisk air in '
#          'Kirkwall today anyway - not much chance of frost I suspect 🤣',
#  'user': {'location': 'Grimbister, Kirkwall, Orkney, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7a'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7b'),
#  'text': 'RT @StiofanNutty: Extraordinary temperatures being recorded today '
#          'across France &amp; Spain. Again highlighting the extent '
#          '&amp;widespread nature o…',
#  'user': {'location': 'Italy'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7c'),
#  'text': 'RT @StiofanNutty: Extraordinary temperatures being recorded today '
#          'across France &amp; Spain. Again highlighting the extent '
#          '&amp;widespread nature o…',
#  'user': {'location': 'Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7d'),
#  'text': 'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch '
#          'Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland '
#          '@bbcweather…',
#  'user': {'location': 'Buckingham '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7e'),
#  'text': 'RT @bbcweather: Major motorway closed and residents in Canberra '
#          'region told to seek shelter from out of control bushfires. Hot and '
#          'windy co…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e7f'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e80'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e81'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Edinburgh'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e82'),
#  'text': 'Extraordinary temperatures being recorded today across France &amp; '
#          'Spain. Again highlighting the extent &amp;widespread na… '
#          'https://t.co/4zjuXQcvF5',
#  'user': {'location': 'Átha Cliath'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e83'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Pacific Quay, Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e84'),
#  'text': '@AndiOram4 @MickeyJPrior @bbcweather Two decent articles on the MetO '
#          'site...\n'
#          '\n'
#          'https://t.co/UX1nYOzn3p\n'
#          '\n'
#          '^ explains t… https://t.co/0zj1110yJo',
#  'user': {'location': 'Penzance, Cornwall '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e85'),
#  'text': '@Alex_Mulcrow93 @bbcweather Our flowers and trees have started too. '
#          "Blossom already. It's not normal",
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e86'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'BBC Pacific Quay, Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e87'),
#  'text': '@MickeyJPrior @bbcweather Well the ground temperature is recorded '
#          'just above the ground I believe just above the su… '
#          'https://t.co/n1M2ase24m',
#  'user': {'location': 'Penzance, Cornwall '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e88'),
#  'text': 'RT @bbcweather: AUSTRALIA: New South Wales and ACT experienced the '
#          'worst of the #heatwave on Saturday\n'
#          '\n'
#          'Canberra had its hottest day on reco…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e89'),
#  'text': 'RT @Ichabodus: Holbeach Hurn #Lincolnshire\n'
#          '@LincsSkies\n'
#          ' \n'
#          '@EarthandClouds2 @StormHour @cloudymamma @BBCWthrWatchers '
#          '@bbcweather @spaldingtod…',
#  'user': {'location': 'Collinsville, VA'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8a'),
#  'text': 'Kirkwall bay, oh bonny Kirkwall bay... looking a bit lively '
#          'tonight... https://t.co/Cqk6D2OOkT https://t.co/LM4nMCgQXw',
#  'user': {'location': 'Kirkwall'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8b'),
#  'text': '@Official_WXUK @MickeyJPrior @bbcweather Is there anything good I '
#          'can read up about frosts and forecasting them.',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8c'),
#  'text': '@bbcweather Hope the trend stays for the weekend..',
#  'user': {'location': 'south Greater Manchester'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8d'),
#  'text': '@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather '
#          '@SimonOKing @StormHour @ThePhotoHour Is it a bird..… '
#          'https://t.co/vUJmMWVVYn',
#  'user': {'location': 'Belfast, Northern Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8e'),
#  'text': '@Official_WXUK @bbcweather The air temperature at ground level must '
#          'be 0° to cause the ice crystals on the surface to form?',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e8f'),
#  'text': '@bbcweather Camborne in Cornwall as well I believe 👍',
#  'user': {'location': 'Penzance, Cornwall '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e90'),
#  'text': '@StevePayne2018 @bbcweather Ah! Global warming? Not ideal, but the '
#          'line of business I’m in I don’t like the cold wi… '
#          'https://t.co/loXcBsUdEM',
#  'user': {'location': 'Dundee, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e91'),
#  'text': '@bbcweather Blimey!!!! 🥶🥶🥶 https://t.co/zG2gaYZeO2',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e92'),
#  'text': '@MickeyJPrior @bbcweather Air frost occurs when the air temp at 2 '
#          'metres reaches -0°C. A ground frost can occur wit… '
#          'https://t.co/JvVoEUQla3',
#  'user': {'location': 'Penzance, Cornwall '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e93'),
#  'text': 'Holbeach Hurn #Lincolnshire\n'
#          'Straight out of the camera. #sooc\n'
#          '@LincsSkies\n'
#          ' \n'
#          '@EarthandClouds2 @StormHour… https://t.co/jY5pgftA9R',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e94'),
#  'text': 'Holbeach Hurn #Lincolnshire\n'
#          '@LincsSkies\n'
#          ' \n'
#          '@EarthandClouds2 @StormHour @cloudymamma @BBCWthrWatchers '
#          '@bbcweather… https://t.co/jgwD4okuNB',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e95'),
#  'text': 'It was 9c and pouring when we were in Santander in June......ho hum '
#          'https://t.co/9elLeHAq0u',
#  'user': {'location': 'Scotland, United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e96'),
#  'text': '@every_station @ScotRail @AlexHynes @bbcweather I was there the '
#          'other day 😊',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e97'),
#  'text': "@Dave91632231 @bbcweather It's winter. It's supposed to be cold. "
#          'There are meant to be frosts. The absence of them… '
#          'https://t.co/G1Jlpf5kr1',
#  'user': {'location': 'Leicestershire'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e98'),
#  'text': '@StevePayne2018 @bbcweather Why? I thought it would be good? Thanks '
#          'in advance for an explanation! 👍🏼',
#  'user': {'location': 'Dundee, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e99'),
#  'text': 'RT @ruths_gallery: A touch of brightness on a dull grey '
#          '#MondayAfternoon at #Twickenham @metoffice  @bbcweather  '
#          '@SallyWeather @itvweather…',
#  'user': {'location': 'Worldwide'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9a'),
#  'text': '@every_station @ScotRail @AlexHynes @bbcweather I saw that train at '
#          'Carsile about 30 minutes ago, I’m on an avanti… '
#          'https://t.co/IJsjzTb25C',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9b'),
#  'text': 'A touch of brightness on a dull grey #MondayAfternoon at #Twickenham '
#          '@metoffice  @bbcweather  @SallyWeather… https://t.co/eLXwcRbRQ4',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9c'),
#  'text': '@every_station @ScotRail @AlexHynes @bbcweather Great photo.',
#  'user': {'location': 'Widnes'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9d'),
#  'text': "@bbcweather What's the difference between air and ground frost?",
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9e'),
#  'text': 'RT @every_station: The cloud formations just now at Gretna Green are '
#          'amazing! 156507 on a Carlisle to Glasgow Central service. \n'
#          '\n'
#          '@ScotRail…',
#  'user': {'location': 'Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902e9f'),
#  'text': 'The cloud formations just now at Gretna Green are amazing! 156507 on '
#          'a Carlisle to Glasgow Central service.… https://t.co/MILaurBXdM',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea0'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'Edinburgh, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea1'),
#  'text': 'RT @Ichabodus: Holbeach Hurn #Lincolnshire\n'
#          'Straight out of the camera. #sooc\n'
#          '@LincsSkies\n'
#          ' \n'
#          '@EarthandClouds2 @StormHour @cloudymamma @BBCWth…',
#  'user': {'location': 'Collinsville, VA'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea2'),
#  'text': '@TravelwithPOwer @ThePhotoHour @metoffice @bbcweather @SallyWeather '
#          '@itvweather @SimonOKing @StormHour Thank you',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea3'),
#  'text': 'Leg of Mutton Pond at Bushy Park #photooftheday  @theroyalparks '
#          '@WildLondon @WWTLondon @StormHour @PhotoHour… '
#          'https://t.co/pAhxZPkPRf',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea4'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'Stirling, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea5'),
#  'text': '@bbcweather Incredible',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea6'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea7'),
#  'text': '@ruths_gallery @ThePhotoHour @metoffice @bbcweather @SallyWeather '
#          '@itvweather @SimonOKing @StormHour Cool! 👍',
#  'user': {'location': 'México.'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea8'),
#  'text': 'RT @every_station: The cloud formations just now at Gretna Green are '
#          'amazing! 156507 on a Carlisle to Glasgow Central service. \n'
#          '\n'
#          '@ScotRail…',
#  'user': {'location': 'Edinburgh, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ea9'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eaa'),
#  'text': 'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch '
#          'Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland '
#          '@bbcweather…',
#  'user': {'location': 'Texas'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eab'),
#  'text': 'Sunshine, rain or snow. For me all of the enjoyment of the weather '
#          'comes from how it feels. ☀️ 🌧 ❄️ https://t.co/fUOgmvCdlJ',
#  'user': {'location': 'Bristol ✈️ San Francisco'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eac'),
#  'text': '@bbcweather Southerly wind ya NERDS, its NOT climate change ffs',
#  'user': {'location': 'Ireland '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ead'),
#  'text': 'thisisfine.jpg https://t.co/MGIQvFLKmB',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eae'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eaf'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Banana Republic'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb0'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Enfield, London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb1'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': '#DearneValley S.Yorkshire - UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb2'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb3'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Tameside, Greater Manchester'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb4'),
#  'text': 'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️',
#  'user': {'location': 'Bristol UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb5'),
#  'text': "@bbcweather This isn't good news 🙁",
#  'user': {'location': 'Leicestershire'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb6'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Cornwall, UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb7'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb8'),
#  'text': 'RT @bbcweather: We are two thirds of the way through meteorological '
#          'winter and some UK locations, including Kirkwall (Orkney), Weybourne '
#          '(N…',
#  'user': {'location': 'Trinidad'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eb9'),
#  'text': 'We are two thirds of the way through meteorological winter and some '
#          'UK locations, including Kirkwall (Orkney), Weyb… '
#          'https://t.co/X7skB5rYxV',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eba'),
#  'text': '.@bbcweather *Again* 1430  GMT @bbcworld news weather summary: '
#          'presenter standing in front of satellite video for P… '
#          'https://t.co/oXmRIxigH2',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebb'),
#  'text': '‘I’m watching you’.  A jackdaw on our balcony on a cloudy afternoon '
#          'at #Twickenham @metoffice  @bbcweather… https://t.co/ygjqFDk1Gg',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebc'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': '日本'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebd'),
#  'text': 'RT @ruths_gallery: ‘I’m watching you’.  A jackdaw on our balcony on '
#          'a cloudy afternoon at #Twickenham @metoffice  @bbcweather  '
#          '@SallyWeathe…',
#  'user': {'location': 'Worldwide'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebe'),
#  'text': 'RT @gazza_d: This is fine https://t.co/76CdECe4al',
#  'user': {'location': 'Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ebf'),
#  'text': '@bbcweather 😱',
#  'user': {'location': 'The Witterings, Sussex'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec0'),
#  'text': '@bbcweather Crazy. Please tell me that we will get some colder '
#          'weather in kent? Every day is in double figures and… '
#          'https://t.co/TkmYJ9joV9',
#  'user': {'location': 'Rochester, kent'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec1'),
#  'text': "@bbcweather Where are the 'I saw snow in winter so climate change "
#          "isn't real' people",
#  'user': {'location': 'Wessex'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec2'),
#  'text': 'RT @gazza_d: This is fine https://t.co/76CdECe4al',
#  'user': {'location': 'On a bike, somewhere in the UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec3'),
#  'text': 'RT @GWestCBayCC: #Greenock #Gourock #Inverclyde #Scotland '
#          '#WeatherAware https://t.co/ueMAxvkj4l',
#  'user': {'location': 'Greenock, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec4'),
#  'text': '@festinagirl yep https://t.co/4s3yS1iPiS and as models predicted as '
#          'we warm up we get more extremes, all the warmes… '
#          'https://t.co/eXVbfB3Nlr',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec5'),
#  'text': 'As of 1300 GMT, we have seen the following temperatures today in '
#          'France and Spain:\n'
#          '\n'
#          'Seillans 26.8C\n'
#          'Santander airpor… https://t.co/feXKwJSRWT',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec6'),
#  'text': 'This is fine https://t.co/76CdECe4al',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec7'),
#  'text': 'RT @gazza_d: This is fine https://t.co/76CdECe4al',
#  'user': {'location': 'London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec8'),
#  'text': 'Stormy seas surrounding the Isle of Skye today 🌊\n'
#          '\n'
#          '@VisitScotland @bbcweather #isleofskye #Scotland #Weather… '
#          'https://t.co/dbsYA9rKTP',
#  'user': {'location': 'Scotland '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ec9'),
#  'text': '@themetoffice @bbcweather just built a natural stone wall on the '
#          'basis it was going to be dry today (as you guys sa… '
#          'https://t.co/Mbcxf2IgJX',
#  'user': {'location': 'somerset'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eca'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'emel gurbeti'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecb'),
#  'text': 'RT @KimGPhoto: Stormy seas surrounding the Isle of Skye today 🌊\n'
#          '\n'
#          '@VisitScotland @bbcweather #isleofskye #Scotland #Weather '
#          '#ScotlandIsNow h…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecc'),
#  'text': '@Silligilli @porridgebrain @cairnstoon @bbcweather',
#  'user': {'location': 'U.K'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecd'),
#  'text': '@YorkshireBird_ @porridgebrain @LevParikian @bbcweather',
#  'user': {'location': 'U.K'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ece'),
#  'text': 'RT @bbcweather: Feeling the forecast through haptic technology. '
#          'Could this be the future of BBC Weather?\n'
#          'https://t.co/u9w2K98EL7 https://t.…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ecf'),
#  'text': '@bbcweather @BBCWthrWatchers @BBCLookEast',
#  'user': {'location': 'Cambridgeshire'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed0'),
#  'text': "@bbcweather We're more likely to see wetter summers in Scotland due "
#          'to the jet stream not moving as far north as it… '
#          'https://t.co/jQZP5ghcl3',
#  'user': {'location': 'Dumfries'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed1'),
#  'text': 'RT @bbcweather: Feeling the forecast through haptic technology. '
#          'Could this be the future of BBC Weather?\n'
#          'https://t.co/u9w2K98EL7 https://t.…',
#  'user': {'location': 'Brooklyn, NY'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed2'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'The world'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed3'),
#  'text': '@JeanneHoffa @theroyalparks @WildLondon @WWTLondon @StormHour '
#          '@photohour @bbcweather @SimonOKing @SallyWeather @itvweather Thank '
#          'you Jeanne',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed4'),
#  'text': 'After a sunny start around #Stirling winds blowing rain clouds '
#          'across (3/2) #WeatherWatcherGraham @BBCScotWeather… '
#          'https://t.co/tOtpDgqBXF',
#  'user': {'location': 'Stirling, Scotland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed5'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'malmö'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed6'),
#  'text': "@Menkvi @bbcweather This isn't climate change just a plume of hot "
#          'air which has been drawing hot air up for about a… '
#          'https://t.co/lpwHdFe6Tw',
#  'user': {'location': 'Dungeon Master '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed7'),
#  'text': 'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed8'),
#  'text': '@alannah213 @barrabest @WeatherCee @BBCNewsNI @BBCTravelShow '
#          '@DiscoverNI @bbcweather Great sky ...',
#  'user': {'location': 'Bailiwick of Guernsey'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ed9'),
#  'text': 'RT @frasergj: After a sunny start around #Stirling winds blowing '
#          'rain clouds across (3/2) #WeatherWatcherGraham @BBCScotWeather '
#          '@BBCAimsir…',
#  'user': {'location': 'The Atmosphere'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eda'),
#  'text': 'RT @simon_weather: Daffodils in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @Me…',
#  'user': {'location': 'Northamptonshire, UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902edb'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…',
#  'user': {'location': 'The world'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902edc'),
#  'text': 'Milan car ban: Drivers ignore anti-pollution measure '
#          'https://t.co/6BtAMWNfLP',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902edd'),
#  'text': 'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch '
#          'Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland '
#          '@bbcweather…',
#  'user': {'location': 'España'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ede'),
#  'text': '@goldfinches12 @metoffice @bbcweather @SallyWeather @itvweather '
#          '@SimonOKing @StormHour @ThePhotoHour Thank you Mart… '
#          'https://t.co/fDMppTyn9L',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902edf'),
#  'text': 'Our partners @ultraleap pioneered this haptic technology. Could it '
#          'be the future of out weather forecasts? Great ex… '
#          'https://t.co/TK5EHYIsVE',
#  'user': {'location': 'Bristol '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee0'),
#  'text': '@ruths_gallery @theroyalparks @WildLondon @WWTLondon @StormHour '
#          '@photohour @bbcweather @SimonOKing @SallyWeather @itvweather Lovely. '
#          '😊',
#  'user': {'location': 'Fullerton, CA'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee1'),
#  'text': 'Early morning calm at Bushy Park #photooftheday  @theroyalparks '
#          '@WildLondon @WWTLondon @StormHour @PhotoHour… '
#          'https://t.co/WTwx3N1nAQ',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee2'),
#  'text': 'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️ '
#          'https://t.co/Nphu3hJVQa',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee3'),
#  'text': 'Serbia (deep ties to Russia)👉 country with the highest rate of '
#          'pollution-related deaths in Europe, according to the… '
#          'https://t.co/esdpkPZbhY',
#  'user': {'location': 'NE OH'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee4'),
#  'text': '@bbcweather https://t.co/QGpJ97PHQQ',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee5'),
#  'text': '@ruths_gallery @metoffice @bbcweather @SallyWeather @itvweather '
#          "@SimonOKing @StormHour @ThePhotoHour That's an amaz… "
#          'https://t.co/4CfjDIwF44',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee6'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee7'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'The world'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee8'),
#  'text': 'RT @GeordieCanary: Has spring arrived ? @ChrisPage90 @WeatherAisling '
#          '@BBCWthrWatchers @bbcweather @StormHour @LensAreLive '
#          'https://t.co/laSb…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ee9'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eea'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': 'Newtownabbey'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eeb'),
#  'text': 'RT @GeordieCanary: Has spring arrived ? @ChrisPage90 @WeatherAisling '
#          '@BBCWthrWatchers @bbcweather @StormHour @LensAreLive '
#          'https://t.co/laSb…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eec'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'Adelaide, South Australia'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eed'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'Worldwide'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eee'),
#  'text': "Cycling through Europe's deadliest air https://t.co/1gL5BK6HMt",
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eef'),
#  'text': 'RT ultraleap "We spot an ultraleap mid-air #haptic array! 👀🌦️ '
#          'https://t.co/ribK44J5Gj"',
#  'user': {'location': 'Bristol UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef0'),
#  'text': 'We spot an @ultraleap mid-air #haptic array! 👀🌦️ '
#          'https://t.co/Nphu3hJVQa',
#  'user': {'location': 'Global'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef1'),
#  'text': '@BBCBreakfast @bbcweather ‘in the north of the country’ - repeat '
#          'after me UK / Britain is not a country - UK / Brit… '
#          'https://t.co/51KeFQLgkm',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef2'),
#  'text': 'RT @GeordieCanary: Has spring arrived ? @ChrisPage90 @WeatherAisling '
#          '@BBCWthrWatchers @bbcweather @StormHour @LensAreLive '
#          'https://t.co/laSb…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef3'),
#  'text': 'RT @ultraleap: We spot an @ultraleap mid-air #haptic array! 👀🌦️ '
#          'https://t.co/Nphu3hJVQa',
#  'user': {'location': 'みんな東京と思っているけど札幌（寒いので出たい）'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef4'),
#  'text': '@GeordieCanary @StormHour @ChrisPage90 @WeatherAisling '
#          '@BBCWthrWatchers @bbcweather @LensAreLive Oh yes 😎 '
#          'https://t.co/QA6TsrZKzQ',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef5'),
#  'text': '@bbcweather Yeah right...I call bullshit!!',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef6'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'The Atmosphere'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef7'),
#  'text': 'RT @JaneDryden4: I warned this would happen. @metoffice uses '
#          'extremely high sensitivity HadGEM3-GA6 model, combined with recently '
#          'debunked…',
#  'user': {'location': 'uk'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef8'),
#  'text': 'Take care on the roads in Scotland today. https://t.co/0sCqsmZysI',
#  'user': {'location': 'United King'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902ef9'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'Strawberry Hill, Twickenham,UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902efa'),
#  'text': '@Omi_233 @bbcweather What BBC propaganda?',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902efb'),
#  'text': 'RT @GeordieCanary: Has spring arrived ? @ChrisPage90 @WeatherAisling '
#          '@BBCWthrWatchers @bbcweather @StormHour @LensAreLive '
#          'https://t.co/laSb…',
#  'user': {'location': 'The Atmosphere'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902efc'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': 'defensar la república !'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902efd'),
#  'text': 'RT @ruths_gallery: Awesome mackerel clouds just now over '
#          '#Twickenham  @metoffice  @bbcweather #MondayMorning @SallyWeather '
#          '@itvweather @Clo…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902efe'),
#  'text': 'Awesome mackerel clouds just now over #Twickenham  @metoffice  '
#          '@bbcweather #MondayMorning @SallyWeather @itvweather… '
#          'https://t.co/eOZy9je83R',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902eff'),
#  'text': '@simon_weather @StormchaserUKEU @carlharlott @DanHolley @stormbell '
#          '@Lowweather @TheSnowDreamer @iainG81 @MetRyan96… '
#          'https://t.co/4q2oqgcDTC',
#  'user': {'location': 'Dungeon Master '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f00'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f01'),
#  'text': '@bbcweather Hope not, we need to fight back against this.',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f02'),
#  'text': 'Has spring arrived ? @ChrisPage90 @WeatherAisling @BBCWthrWatchers '
#          '@bbcweather @StormHour @LensAreLive https://t.co/laSbcPcfWU',
#  'user': {'location': 'Norwich, Norfolk, UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f03'),
#  'text': 'RT @ruths_gallery: It looks as if that jackdaw is making a contrail '
#          '😳🤣 Sunny spells are forecast for #Twickenham before a cloudy '
#          'afternoon…',
#  'user': {'location': 'Worldwide'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f04'),
#  'text': '@bbcweather Nothing new here, more climate propaganda and hysteria '
#          'from the BBC. The license fee really must go and… '
#          'https://t.co/gdIroLIRwx',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f05'),
#  'text': 'Daffodils in Great Yarmouth @StormchaserUKEU @carlharlott @danholley '
#          '@stormbell @Lowweather @TheSnowDreamer… https://t.co/CZsW5g6Yyt',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f06'),
#  'text': '@AbhaPaulina @VisitScotland @bbcweather @BBCScotland Gorgeous scenes '
#          'on Saturday 😍',
#  'user': {'location': 'Loch Lomond'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f07'),
#  'text': "@JudePri14876016 @bbcweather You'll either drown or starve to death "
#          'if we get to that point.',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f08'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': 'Belfast, Northern Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f09'),
#  'text': 'Does anyone else think it is rather fitting that the UK national '
#          'anthem contains a pessimistic #weather forecast at… '
#          'https://t.co/X9x7qo7aZs',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0a'),
#  'text': 'RT @bbcweather: A day of #summer extremes in New Zealand on Sunday.\n'
#          '\n'
#          'Whilst Napier, on North Island, experienced its #hottestdayonrecord '
#          'at…',
#  'user': {'location': 'LONDON/NYC'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0b'),
#  'text': '@1PaulMichael @VisitScotland @bbcweather @BBCScotland I must say it '
#          'took me over a minute to register that it’s Ben… '
#          'https://t.co/Z18sbi9nLZ',
#  'user': {'location': 'Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0c'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0d'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0e'),
#  'text': 'I warned this would happen. @metoffice uses extremely high '
#          'sensitivity HadGEM3-GA6 model, combined with recently de… '
#          'https://t.co/kHK47JCiPY',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f0f'),
#  'text': '@bbcweather Perhaps dry hot summers could become the norm in '
#          'Scotland',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f10'),
#  'text': 'RT @simon_weather: Daffodils in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @Me…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f11'),
#  'text': '@bbcweather Yep, with #WeatherModification....',
#  'user': {'location': 'Ireland '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f12'),
#  'text': "@bbcweather Good let's make 25c the average",
#  'user': {'location': 'Dungeon Master '}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f13'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f14'),
#  'text': 'It looks as if that jackdaw is making a contrail 😳🤣 Sunny spells are '
#          'forecast for #Twickenham before a cloudy after… '
#          'https://t.co/YrwBR88OX5',
#  'user': {'location': 'Twickenham, Greater London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f15'),
#  'text': "Dry, hot summers could become 'norm' in Scotland "
#          'https://t.co/8xgEL0uyYV',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f16'),
#  'text': '@AbhaPaulina @VisitScotland @bbcweather @BBCScotland At this time of '
#          'year the Ben would often be capped in snow. Beautiful sight.',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f17'),
#  'text': 'RT @Iceman26061: Lovely pink clouds from yesterday🌅☁️ #clouds '
#          '#sunset #weather #photography #Northamptonshire #loveukweather '
#          '@LensAreLive @…',
#  'user': {'location': 'World!!!'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f18'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'Wherever my ❤️🐺🐅 leads me!'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f19'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': 'Belfast'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1a'),
#  'text': 'Porthleven 2014 the year the inner harbour baulks were smashed apart '
#          'and lots of boats sunk/damaged… https://t.co/O14qq5QACO',
#  'user': {'location': 'Helston, Cornwall'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1b'),
#  'text': 'RT @therileyshot: Some nice colours this morning whilst I have my '
#          'morning breakfast battle with the little munchkin! Have a fab week '
#          'everyo…',
#  'user': {'location': 'Plauen, Deutschland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1c'),
#  'text': 'Sunrise in Great Yarmouth @StormchaserUKEU @carlharlott @danholley '
#          '@stormbell @Lowweather @TheSnowDreamer @iainG81… '
#          'https://t.co/RNatAcYBDn',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1d'),
#  'text': 'RT @therileyshot: Some nice colours this morning whilst I have my '
#          'morning breakfast battle with the little munchkin! Have a fab week '
#          'everyo…',
#  'user': {'location': ''}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1e'),
#  'text': 'This IS not normal #10 https://t.co/vRyhmr4PbV',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f1f'),
#  'text': 'RT @simon_weather: Sunrise in Great Yarmouth @StormchaserUKEU '
#          '@carlharlott @danholley @stormbell @Lowweather @TheSnowDreamer '
#          '@iainG81 @MetR…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f20'),
#  'text': 'RT @absolutoursuk: #Mevagissey meanders on a #winter '
#          'afternoon.#fishinglife @ILoveCornwallUK @VisitSWEngland @WhatsonSW '
#          '@cornwallfilming @C…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f21'),
#  'text': 'More local heat records tumbled in north on Monday\n'
#          '\n'
#          'Meanwhile, Milford Sound recorded almost 500mm (over a months w… '
#          'https://t.co/Wur18q1ruY',
#  'user': {'location': 'Broadcasting House, London'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f22'),
#  'text': '@BBCWthrWatchers @bbcweather @carolkirkwood @Hudsonweather @Abbiedew '
#          '@KeeleyDonovan @katerinaweather @lottyleeming… '
#          'https://t.co/I5bZjX7Dh8',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f23'),
#  'text': 'RT @MetMattTaylor: More local heat records tumbled in north on '
#          'Monday\n'
#          '\n'
#          'Meanwhile, Milford Sound recorded almost 500mm (over a months worth…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f24'),
#  'text': '@therileyshot @BBCLookNorth @bbcweather @itvweather @LensAreLive '
#          '@Liam_Ball92 @Welcome2Yorks Lovely photograph',
#  'user': {'location': 'Wimbledon  #RespectYourPolice'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f25'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f26'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': 'London, UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f27'),
#  'text': 'Some nice colours this morning whilst I have my morning breakfast '
#          'battle with the little munchkin! Have a fab week… '
#          'https://t.co/qnCajuANja',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f28'),
#  'text': 'Monday morning setting. @BBCNWT @bbcweather #Boothstown #Manchester '
#          '#sunrise #sunrisephotography #colours https://t.co/M1Z6Zv5dHz',
#  'user': {'location': 'Manchester,UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f29'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2a'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': 'Scotland, United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2b'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2c'),
#  'text': 'RT @bbcweather: Gales across Scotland later tomorrow. Gusts of '
#          '60-70mph for northern &amp; western Scotland and up to 80mph for the '
#          'Western Isl…',
#  'user': {'location': 'Wellington City, New Zealand'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2d'),
#  'text': 'RT @dunbar44: A stunning Rainbow over the Giants Causeway \n'
#          '\n'
#          '@GCausewayNT @nationaltrust @NationalTrustNI @newslineweather '
#          '@barrabest @Disco…',
#  'user': {'location': 'Belfast, Northern Ireland'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2e'),
#  'text': 'A bright, mild and windy day. Showers in the northwest, some rain '
#          'developing in southern England. Winds strengthen… '
#          'https://t.co/IByZz4C5te',
#  'user': {'location': 'United Kingdom'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f2f'),
#  'text': 'RT @bbcweather: Gales across Scotland later tomorrow. Gusts of '
#          '60-70mph for northern &amp; western Scotland and up to 80mph for the '
#          'Western Isl…',
#  'user': {'location': 'Inverness'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f30'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': 'UK'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f31'),
#  'text': '@1PaulMichael @VisitScotland @bbcweather @BBCScotland Indeed my '
#          'friend , was by chance driving by and couldn’t resist',
#  'user': {'location': 'Glasgow'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f32'),
#  'text': 'RT @AbhaPaulina: Beautiful 1st of February on the shores of Loch '
#          'Lomond #scotland #beautifulday #PictureOfTheDay @VisitScotland '
#          '@bbcweather…',
#  'user': {'location': 'Sedona, AZ'}}
# {'_id': ObjectId('67e602a8d90ddd6ec2902f33'),
#  'text': 'RT @bbcweather: A bright, mild and windy day. Showers in the '
#          'northwest, some rain developing in southern England. Winds '
#          'strengthen with gus…',
#  'user': {'location': ''}}

# %% [markdown]
# 10.2 Reduce the number of rows

# %%
"""db.projWeather.aggregate([
     {$limit: 50},
     {$out:"newWeather"} ])
"""
# Syntax difference: the various parameters must be in quotes
projcol.aggregate([
    {'$limit': 50},
    {'$out': "newWeather"}
])

# %%
# Check that the new collection exists with the required data:
# db.newWeather.count()
# Create a variable called newcol to hold the new collection
newcol = mydb["newWeather"]
print (newcol.count_documents({}))
#Compared to projWeather:
print (projcol.count_documents({}))
# Out:
# 50
# 250

# %% [markdown]
# 11. Further Analysis
# This code counts the top Hashtags and mentions in any tweets where ‘sun’ is mentioned.

# %%
import operator

def print_features(set, type):
    """
    Print the top features (hashtags or mentions) and their counts

    Args:
    set (list): Sorted list of tuples (feature, count)
    type (str): Type of feature ('hashtags' or 'mentions')
    """
    print(f'\nTop 10 {type}:')
    print('----------------')
    for item in set:
        print(f'{item[0]} - {str(item[1])}')

def count_features(tweets):
    """
    Count and sort hashtags and mentions in a list of tweets

    Args:
    tweets (list): List of tweet texts
    """
    tag_dict = {}
    mention_dict = {}

    for tweet_text in tweets:
        # Convert to lowercase and split into words
        tweet = str(tweet_text).lower()
        tweet_tokenized = tweet.split()

        for word in tweet_tokenized:
            # Count Hashtags
            if word.startswith('#') and len(word) > 1:
                # Remove any punctuation
                key = word.strip('.,!?')
                tag_dict[key] = tag_dict.get(key, 0) + 1

            # Count Mentions
            if word.startswith('@') and len(word) > 1:
                # Remove any punctuation
                key = word.strip('.,!?')
                mention_dict[key] = mention_dict.get(key, 0) + 1

    # Get top 10 hashtags
    top_tags = dict(sorted(tag_dict.items(), key=operator.itemgetter(1), reverse=True)[:10])
    top_tags_sorted = sorted(top_tags.items(), key=lambda x: x[1], reverse=True)
    print_features(top_tags_sorted, 'hashtags')

    # Get top 10 mentions
    top_mentions = dict(sorted(mention_dict.items(), key=operator.itemgetter(1), reverse=True)[:10])
    top_mentions_sorted = sorted(top_mentions.items(), key=lambda x: x[1], reverse=True)
    print_features(top_mentions_sorted, 'mentions')

# %%
# Find the top 10 hastags and mentions for tweets that include sun
# Use the new collection: newcol
tweet_df = newcol.find({'text':{'$regex':'sun'}}, {'text':1})
count_features(tweet_df)
# Out:
# Top 10 hashtags:
# ----------------
# #stirling - 5
# #weatherwatcherg…'} - 3
# #weatherwatchergraham - 2
#
# Top 10 mentions:
# ----------------
# @frasergj: - 5
# @stiruni - 3
# @bbcscotweather - 2
# @bbcaimsir…'} - 2
